# %%
from pathlib import Path
import pandas as pd

# %%
PROJECT_DIR = Path(__file__).resolve().parent
SOLD_PATH = PROJECT_DIR / "sold.csv"
LISTINGS_PATH = PROJECT_DIR / "listings.csv"
OUTPUT_DIR = PROJECT_DIR / "outputs" / "week2_3"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 PROJECT_DIR = Path(__file__).resolve().parent
#       2 SOLD_PATH = PROJECT_DIR / "sold.csv"
#       3 LISTINGS_PATH = PROJECT_DIR / "listings.csv"
#
# NameError: name '__file__' is not defined
